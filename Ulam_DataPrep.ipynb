# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import sqlite3

# %%
def get_dish_urls():
    """Retrieve URLS for dishes under chicken, pork, and beef categories"""
    # Limit main ingredients to three types of meat
    meats = ['chicken', 'pork', 'beef']

    # Prepare dish URLs holder
    dish_urls = {}

    # Loop through each meat types
    for meat in meats:

        # Get HTML for the category page
        response = requests.get(
            f'https://panlasangpinoy.com/{meat}-recipes/'
        )
        soup = BeautifulSoup(response.text)

        # Get number of pages
        pagination = soup.select_one(
            "div[class='archive-pagination pagination']"
        )
        last_page = pagination.select_one(
            "li[class='pagination-omission'] + li"
        )
        num_pages = int(last_page.select_one("a").contents[1])

        # Loop through each pages per meat type
        for n in np.arange(1, num_pages+1):
            response = requests.get(
                f'https://panlasangpinoy.com/{meat}-recipes/page/{n}/'
            )
            soup = BeautifulSoup(response.text)

            # Store dish URL
            for dish in soup.select("a[class='entry-title-link']"):
                dish_name = dish.contents[0]
                dish_urls[dish_name] = dish['href']
                
    print("Extraction of URLs done. Total number of dishes:", len(dish_urls))

    return dish_urls

def get_ingredients(dish_urls):
    """Get ingredients for all dishes"""
    dish_dict = {}

    for key, url in dish_urls.items():
        print("Getting details for: ",key)
        response = requests.get(url)
        soup = BeautifulSoup(response.text)

        dish_details = {}

        try:
            dish_details['course'] = soup.select_one(
                "span[class='wprm-recipe-course "
                "wprm-block-text-normal']"
            ).contents[0]
        except AttributeError:
            dish_details['course'] = np.nan

        try:
            dish_details['cuisine'] = soup.select_one(
                "span[class='wprm-recipe-cuisine "
                "wprm-block-text-normal']"
            ).contents[0]
        except AttributeError:
            dish_details['cusine'] = np.nan
        
        try:
            dish_details['prep_time'] = soup.select_one(
                "span[class='wprm-recipe-details-label wprm-block-text-bold "
                "wprm-recipe-time-label wprm-recipe-prep-time-label'] + span"
            ).text
        except AttributeError:
            dish_details['prep_time'] = np.nan

        try:
            dish_details['cook_time'] = soup.select_one(
                "span[class='wprm-recipe-details-label wprm-block-text-bold "
                "wprm-recipe-time-label wprm-recipe-cook-time-label'] + span"
            ).text
        except AttributeError:
            dish_details['cook_time'] = np.nan
            
        try:
            dish_details['total_time'] = soup.select_one(
                "span[class='wprm-recipe-details-label wprm-block-text-bold "
                "wprm-recipe-time-label wprm-recipe-total-time-label'] + span"
            ).text
        except AttributeError:
            dish_details['total_time'] = np.nan

        try:
            servings = soup.select_one(
                "span[class='wprm-recipe-details-label wprm-block-text-bold "
                "wprm-recipe-servings-label']"
            ).next_sibling.text
            dish_details['servings'] = int(re.findall('\d+', servings)[0])
        except AttributeError:
            dish_details['servings'] = np.nan

        try:
            dish_details['calories'] = soup.select_one(
                "span[class='wprm-recipe-nutrition-with-unit']"
            ).text
        except AttributeError:
            dish_details['calories'] = np.nan

        for ing in soup.select("li[class='wprm-recipe-ingredient']"):
            ing_name = ing.select_one(
                "span[class='wprm-recipe-ingredient-name']"
            ).text
            try:
                str_amount = ing.select_one(
                    "span[class='wprm-recipe-ingredient-amount']"
                ).text
                str_unit = ing.select_one(
                    "span[class='wprm-recipe-ingredient-unit']"
                ).text
                dish_details[ing_name] = get_weight(str_amount, str_unit)
            except AttributeError:
                dish_details[ing_name] = get_weight(ing_name, ing_name)
            
        dish_dict[key] = dish_details
        
    return dish_dict

def get_weight(str_amount, str_weight):
    """Transform different measurements into base units"""
    amount = 0
    div_weight = 1
    
    # Set dictionary of vulgar fraction unicode characters
    vul_frac = {
        '¼':1/4,
        '½':.5,
        '¾':3/4,
        '⅐':1/7,
        '⅑':1/9,
        '⅒':.1,
        '⅓':1/3,
        '⅔':2/3,
        '⅕':.2,
        '⅖':.4,
        '⅗':.6,
        '⅘':.8,
        '⅙':1/6,
        '⅚':5/6,
        '⅛':1/8,
        '⅜':3/8,
        '⅝':5/8,
        '⅞':7/8
    }

    # Check for vulgar fraction characters
    for vul_char, frac in vul_frac.items():
        if str_amount.find(vul_char) != -1:
            amount += frac
            break
    
    # Check for typed fractions
    frac_list = re.findall(r'(\d+)/(\d+)', str_amount)
    if frac_list != []:
        num_frac, den_frac = frac_list[0]
        amount += int(num_frac) / int(den_frac)
    
    # Check for whole number
    whole_num_list = re.findall(r'(?<!/)(\d+)(?!/)', str_amount)
    if whole_num_list != []:
        amount += int(whole_num_list[0])
        
    # Add one if amount is detected
    if amount == 0:
        amount += 1
        
    # Set unit-value mappings
    unit_list = {
        'lb': 0.00220462,
        'bunch': 0.1,
        'liter': 0.236588,
        'quart': 0.25,
        'pinch': 0.355625,
        'pint': 0.5,
        'oz': 8,
        'ounce': 8,
        'thumb': 9.5,
        'tablespoon': 16,
        'tbsp': 16,
        'tsp': 48,
        'ml': 236.588
    }
    
    # Check for units
    for unit_name, unit_val in unit_list.items():
        if str_weight.find(unit_name) > -1:
            div_weight = unit_val
    
    # Compute weight
    weight = amount / div_weight
    
    return weight

def prepare_df(dish_dict):
    '''Create DataFrame out of dish dictionary'''
    df_ing = pd.DataFrame.from_dict(dish_dict).T
    df_ing = df_ing[df_ing.cuisine.str.contains('Filipino', na=False)]

    df_ing = df_ing.drop(columns=["course","cuisine","prep_time","cook_time","total_time","servings","calories"])
    df_ing = df_ing.sort_index(axis=1)
    df_ing = df_ing.dropna(axis=1, how='all')
    df_ing.fillna(0)
    
    cat_ing_dict = {
        'yeast': r'(yeast)',
        'wrapper': r'(wrapper)',
        'worcestershire_sauce': r'(worcestershire)',
        'winged_bean': r'(winged bean)',
        'vinegar': r'(vinegar)',
        'turmeric': r'(tumeric)',
        'tomato': r'(tomato)',
        'tofu': r'(tofu)',
        'toasted_rice_powder': r'(toasted rice powder)',
        'taro': r'(taro)',
        'sweet_potato': r'(sweet potato)',
        'sugar': r'(sugar)',
        'star_anise': r'(star anise)',
        'squash': r'(kalabasa|squash)',
        'soy_sauce': r'(soy sauce)',
        'sinigang_mix': r'(sinigang)',
        'shortening': r'(shortening)',
        'sesame_oil': r'(sesame oil)',
        'scallion': r'(scallion)',
        'sayote': r'(sayote)',
        'salted_egg': r'(salted egg)',
        'safflower_oil': r'(safflower oil)',
        'raisins': r'(raisins)',
        'radish': r'(radish)',
        'potato': r'(potato)',
        'pork_insides': r'(pig’s liver|pig’s heart|pig’s small intestine|bung|pig cheeks|pig heart|pig kidney|pig stomach|pork ears|pork large intenstine|pork liver|small intestine)',
        'pork_fat': r'(pork fat)',
        'pork_stock': r'(pork broth|pork stock|pork cube)',
        'pork_blood': r'(pork blood)',
        'pork_and_beans': r'(pork and beans)',
        'pie_crust': r'(pie)',
        'pickle': r'(pickle|relish)',
        'pepper_leaf': r'(pepper leaves)',
        'pechay': r'(pechay)',
        'peanut': r'(peanut)',
        'patola': r'(patola)',
        'parsley': r'(parsley)',
        'paprika': r'(paprika)',
        'papaya': r'(papaya)',
        'oyster_sauce': r'(oyster)',
        'onion': r'(onion)',
        'olive_oil': r'(olive oil)',
        'olive': r'(olive)',
        'okra': r'(okra)',
        'nutmeg': r'(nutmeg)',
        'noodle': r'(noodle|pancit|sotanghon|misua|miswa)',
        'mushroom': r'(mushroom)',
        'munggo': r'(mung)',
        'mirin': r'(mirin)',
        'mayonnaise': r'(mayonnaise)',
        'malunggay': r'(malunggay)',
        'liver_spread': r'(liver)',
        'lemongrass': r'(lemongrass)',
        'leeks': r'(leeks)',
        'lechon_sauce': r'(lechon)',
        'kasubha': r'(kasubha)',
        'kangkong': r'(spinach|kangkong)',
        'jicama': r'(jicama)',
        'jackfruit': r'(jackfruit)',
        'ice': r'(ice)',
        'hotdog': r'(hotdog)',
        'hot_sauce': r'(hot)',
        'honey': r'(honey)',
        'hoisin_sauce': r'(hoisin)',
        'green_pea': r'(green pea|pigeon pea)',
        'green_bean': r'(green beans|sitaw|snake beans|string beans|snap pea|snow pea)',
        'glutinous_rice': r'(glutinous rice)',
        'ginger': r'(ginger)',
        'ginataang_gulay_mix': r'(ginataang)',
        'garlic': r'(garlic)',
        'flour': r'(flour)',
        'eggplant': r'(eggplant|talong)',
        'egg': r'(egg)',
        'curry_powder': r'(curry)',
        'cucumber': r'(cucumber)',
        'cream': r'(cream)',
        'cooking_wine': r'(wine)',
        'cooking_oil': r'(cooking oil|vegetable oil)',
        'coconut_water': r'(coconut water)',
        'coconut_milk': r'(coconut cream|coconut milk)',
        'coconut_meat': r'(coconut meat)',
        'clear_soda': r'(7-up|sprite|clear softdrink)',
        'cinnamon': r'(cinnamon)',
        'sausage': r'(chinese sauage|chorizo)',
        'chicken_stock': r'(chicken broth|chicken cube)',
        'chicharon': r'(chicharon)',
        'cheese': r'(cheese)',
        'celery': r'(celery)',
        'carrot': r'(carrot)',
        'canned_meat': r'(potted meat|luncheon meat)',
        'calamansi': r'(calamansi|lemon|lime)',
        'cabbage': r'(cabbage)',
        'butter': r'(butter|margarine)',
        'broccoli': r'(broccoli)',
        'bread': r'(bread)',
        'bok_choy': r'(bok choy|bokchoy)',
        'black_soda': r'(coke|cola)',
        'black_bean': r'(black bean)',
        'beer': r'(beer)',
        'beef_insides': r'(lard|cow|beef heart|beef kidney|beef large instestine|beef liver|beef neck bone|beef small intestine|bile|tripe|tongue|tripe|lengua)',
        'beef_stock': r'(beef cube|beef bouillon|bulalo|beef broth|beef stock)',
        'bay_leaf': r'(bay)',
        'bamboo_shoots': r'(bamboo shoots)',
        'baking_powder': r'(baking powder)',
        'annatto': r'(annatto)',
        'ampalaya': r'(ampalaya)',
        'adobo_sauce': r'(adobo)',
        'achiote': r'(achiote)',
        'tomato_liquid': r'(ketchup|tomato sauce|tomato paste|spaghetti sauce)',
        'banana_flower': r'(blossom)',
        'pepper': r'(white pepper|black pepper|crushed pepper|peppercorn)',
        'chili': r'(chili|pepper flakes|serrano pepper|sili|jalapeno|ghost pepper|green pepper)',
        'bell_pepper': r'(bell pepper)',
        'bagoong': r'(alamang|shrimp paste|balaw)',
        'liquid_seasoning': r'(liquid seasoning|savorrich|marinade)',
        'chickpea': r'(chick pea|garbanzos)',
        'chicken_insides': r'(chicken gizzard|chicken hear|chicken liver)',
        'cornstarch': r'(cornstarch)',
        'corned_beef': r'(corned beef)',
        'fish_sauce': r'(fish sauce)',
        'pineapple_juice': r'(pineapple juice|juice from the canned tidbits)',
        'shrimp_cube': r'(shrimp cube)',
        'watermelon': r'(watermelon)',
        'milk': r'(milk)',
        'pea': r'(pea)',
        'pasta': r'(spaghetti|macaroni)',
        'shrimp': r'(shrimp)',
        'pineapple': r'(pineapple)',
        'water': r'(water)',
        'salt': r'(salt)',
        'rice': r'(rice|sinangag)',
        'pork': r'(pork|pig|lechon)',
        'corn': r'(corn)',
        'chicken': r'(chicken)',
        'beef': r'(beef|steak|oxtail|ox tail|sirloin|bistek)',
        'banana': r'(banana|plantain)'
    }

    # Create new DataFrame
    df_new = pd.DataFrame(index=df_ing.index)

    # Loop through the categories
    for cat_name, cat_regex in cat_ing_dict.items():
        # Look for columns that contains the query
        ing_filter = (
            df_ing.columns.to_series()
            .str.contains(cat_regex, case=False, regex=True)
        )

        # Filter columns that satisfy the query
        filter_cols = ing_filter[ing_filter].index
        
        print(f"Columns obtained for {cat_name}:", filter_cols)

        # Add columns to the new DataFrame
        df_new[cat_name] = df_ing[filter_cols].sum(axis=1)

        # Drop columns to prevent reusing of ingredients
        df_ing.drop(columns=filter_cols, inplace=True)
    
    df_new = df_new.rename_axis('dish_name').reset_index()
    return df_new

def export_sql(df_dish):
    """Export DataFrame to SQL file"""
    # Open connection to DB file
    conn = sqlite3.connect('ulam.db')

    # Transform DataFrame into DB table
    df_dish.to_sql('rekado', con=conn, if_exists='replace', index=False)
    
    # Close connection
    conn.close()

# %%
dish_urls = get_dish_urls()
# Out:
# Extraction of URLs done. Total number of dishes: 788

# %%
dish_dict = get_ingredients(dish_urls)
# Out:
# Getting details for:  Sinarsahang Manok
# Getting details for:  Pinoy Chicken Curry Recipe
# Getting details for:  Ketchup Fried Chicken
# Getting details for:  Chicken Barbecue
# Getting details for:  Father’s Day Chicken Macaroni Salad
# Getting details for:  Chicken Afritada Recipe
# Getting details for:  Chicken Paksiw Recipe
# Getting details for:  Chicken Igado
# Getting details for:  Sinigang Mix Inasal na Manok
# Getting details for:  Chicken Binagoongan Recipe
# Getting details for:  Sweet and Sour Chicken Meatballs
# Getting details for:  Pineapple Chicken Afritada
# Getting details for:  Making McDonalds Style Chicken Nuggets at home
# Getting details for:  How to Make Crispy Fried Chicken (Spicy Version)
# Getting details for:  How to Cook Chicken Kare-Kare sa Gata
# Getting details for:  Sweet Chicken Asado Recipe
# Getting details for:  Chicken Enchilada Casserole Recipe
# Getting details for:  Chicken Teriyaki, Brown Rice, and Sunny Side Up Egg Recipe
# Getting details for:  Homemade Chicken Noodle Soup Recipe
# Getting details for:  Chicken Egg Fried Rice Recipe
# Getting details for:  Rosemary Baked Chicken Recipe with Vegetables
# Getting details for:  Easy Chicken Barbecue Recipe
# Getting details for:  Pancit Bato Noodle Soup
# Getting details for:  Rotisserie Chicken Arroz Caldo Recipe
# Getting details for:  Eggplant and Ground Chicken Omelet
# Getting details for:  Easy Chicken Parm
# Getting details for:  Chicken Pasta Casserole
# Getting details for:  Chicken Pita
# Getting details for:  Billy’s BBQ Chicken Recipe
# Getting details for:  Friday Chicken Noodle Soup
# Getting details for:  Spring Fried Chicken
# Getting details for:  Kinamunggayang Manok Recipe
# Getting details for:  Sayote Guisado with Chicken and Shrimp
# Getting details for:  Chicken with Ampalaya in Oyster Sauce
# Getting details for:  Easy Chicken Curry
# Getting details for:  Asian Fried Chicken
# Getting details for:  Chicken and Ham Sopas Recipe
# Getting details for:  Chicken Carbonara
# Getting details for:  Barbecued Chicken Lettuce Wrap
# Getting details for:  Chicken Siomai
# Getting details for:  Sizzling Chicken Sisig
# Getting details for:  Arroz Caldo with Tokwa (Chicken Congee with Fried Tofu)
# Getting details for:  Fried Chicken Potato Salad
# Getting details for:  Pesang Manok (Chicken Soup in Ginger Broth)
# Getting details for:  Chicken Giniling with Green Peas
# Getting details for:  Bean Sprout Chicken
# Getting details for:  Asian Chicken Soup
# Getting details for:  Asian Grilled Chicken and Corn
# Getting details for:  Pulled Chicken BBQ Sandwich recipe
# Getting details for:  Sautéed String Beans with Chicken
# Getting details for:  Easy Chicken Tacos
# Getting details for:  Sweet Chicken Spaghetti
# Getting details for:  Chicken Piccata
# Getting details for:  Chicken Pesto Pasta
# Getting details for:  Basil Chicken Recipe
# Getting details for:  Chicken with Broccoli Recipe
# Getting details for:  Creamy Chicken with Mushroom Recipe
# Getting details for:  General Tso Chicken Recipe
# Getting details for:  Fried Chicken Breast with Creamy Lemon Sauce Dip
# Getting details for:  Roasted Chicken Quarter Recipe
# Getting details for:  Chicken Galantina Recipe
# Getting details for:  Paella Mixta Recipe
# Getting details for:  Easy Chicken Tinola Recipe
# Getting details for:  Chicken Salad Wrap
# Getting details for:  Chicken Soup Recipe
# Getting details for:  Chicken Fried Rice Recipe
# Getting details for:  Chicken Salad with Apples and Grapes
# Getting details for:  Chicken Spring Roll Recipe
# Getting details for:  Pineapple Fried Chicken Recipe
# Getting details for:  Chicken and Baby Corn Stir Fry
# Getting details for:  Easy Chicken Teriyaki Recipe
# Getting details for:  Dusty Fried Chicken Recipe (How to Cook Simple Fried Chicken)
# Getting details for:  Baked Garlic Rosemary Chicken Recipe
# Getting details for:  Baked Chicken and Vegetable Stir Fry Recipe
# Getting details for:  Chicken Pasta Alfredo Recipe
# Getting details for:  Grilled Chicken and Corn
# Getting details for:  White Chicken Chili Recipe
# Getting details for:  Seared Chicken with Mixed Vegetables
# Getting details for:  Creamy Chicken Breast Recipe
# Getting details for:  Easy Basil and Tomato Chicken Breast
# Getting details for:  Chicken a la King Recipe
# Getting details for:  Chicken Spaghetti Recipe
# Getting details for:  Chicken Marsala Recipe
# Getting details for:  Oriental Lemon Chicken Recipe (How to Cook Lemon Chicken)
# Getting details for:  Chicken Satay with Peanut Sauce Recipe
# Getting details for:  Oven Baked Chicken Recipe
# Getting details for:  Asian Chicken Stir Fry Recipe
# Getting details for:  Chicken Kebab Recipe
# Getting details for:  Sinampalukang Manok Recipe
# Getting details for:  Garlic Fried Chicken
# Getting details for:  Buffalo Chicken Wings Recipe
# Getting details for:  Chicken Feet Adobo
# Getting details for:  Chicken Binakol
# Getting details for:  Cilantro Lime Chicken
# Getting details for:  Chicken Fajita Recipe
# Getting details for:  Tandoori Chicken Recipe
# Getting details for:  Grilled Chicken and Spinach Salad Recipe
# Getting details for:  Kung Pao Chicken Recipe
# Getting details for:  Jocelyn’s Chicken Curry
# Getting details for:  Sarah’s Creamy Chicken Macaroni Soup
# Getting details for:  Ann’s Quick Chicken Salad
# Getting details for:  Jennifer’s Breaded Chicken with Mango Sauce
# Getting details for:  Grilled Chicken Salad
# Getting details for:  Fried Chicken Gizzard
# Getting details for:  Garlic Parmesan Chicken Wings Recipe
# Getting details for:  Shared Recipe. Millie’s Pininyahang Manok
# Getting details for:  Rotini Chicken Alfredo Recipe
# Getting details for:  Chicken Pandan
# Getting details for:  Tarragon Chicken Salad
# Getting details for:  Buttermilk Fried Chicken
# Getting details for:  Chicken Teriyaki Recipe
# Getting details for:  Roasted Chicken Recipe
# Getting details for:  Chicken Inasal Recipe
# Getting details for:  Pinatisang Manok
# Getting details for:  Chicken Sopas Recipe
# Getting details for:  Chicken Parmesan Recipe
# Getting details for:  Chicken Noodle Soup Recipe
# Getting details for:  Chicken Asado Recipe
# Getting details for:  Chicken Satay with Peanut Sauce
# Getting details for:  Grilled Chicken with Mandarin Salad
# Getting details for:  Roast Chicken Recipe
# Getting details for:  Molo Soup
# Getting details for:  Chicken Cordon Bleu
# Getting details for:  Ginataang Manok Recipe
# Getting details for:  Cashew Chicken Recipe
# Getting details for:  Chicken Empanada
# Getting details for:  Max’s style Fried Chicken
# Getting details for:  Fried Chicken with White Gravy Recipe
# Getting details for:  Recipe for Chicken Macaroni Salad
# Getting details for:  Filipino Fried Chicken Recipe
# Getting details for:  Spicy Chicken Feet
# Getting details for:  Pata Estofado
# Getting details for:  How to Cook Dinuguan Using Sinigang Mix
# Getting details for:  Binagoongan Bagnet with Talong
# Getting details for:  Nagmamantikang Pork Adobo
# Getting details for:  Binagoongang Talong
# Getting details for:  Air Fryer Crispy Pata
# Getting details for:  Siopao Asado Recipe
# Getting details for:  Pork Menudo Recipe
# Getting details for:  Pork Caldereta Recipe
# Getting details for:  Bicol Express Gising-gising Recipe
# Getting details for:  Pork Steak Recipe (How to Cook Pork Chop Steak)
# Getting details for:  Crispy Kare-kare Recipe
# Getting details for:  Pork Katsu Curry
# Getting details for:  Bicol Express Recipe
# Getting details for:  Crispy Pork Belly Chips
# Getting details for:  Easy Meatballs Recipe
# Getting details for:  Reuben Sandwich
# Getting details for:  Papis Recipe
# Getting details for:  Quick Roast Beef Sandwich
# Getting details for:  Bulalo Beef Mami
# Getting details for:  Beef Bicol Express
# Getting details for:  Pepper Steak
# Getting details for:  Ginger Beef Stir Fry
# Getting details for:  Easy Roast Beef Sandwich
# Getting details for:  Tokwat Baka (Fried Tofu and Grilled Beef in Vinegar Sauce)
# Getting details for:  Sauteed Flank Steak with Bok Choy and String Beans
# Getting details for:  Spicy Beef Noodle Soup
# Getting details for:  Easy Meatloaf Recipe
# Getting details for:  Basil Beef Recipe
# Getting details for:  Beef Empanadas Recipe
# Getting details for:  Easy Beef with Broccoli
# Getting details for:  Slow Cooker Beef Stew
# Getting details for:  Teriyaki Bistek Recipe
# Getting details for:  Chicago Style Hotdog
# Getting details for:  Misua with Ground Beef and Zucchini Soup
# Getting details for:  Easy Porterhouse Steak Recipe
# Getting details for:  Lengua Con Setas Recipe
# Getting details for:  Ground Beef Spaghetti Alfredo
# Getting details for:  Ground Beef Basil and Tomato Frittata
# Getting details for:  Carne Asada Burrito Recipe
# Getting details for:  T-Bone Steak Sauteed with Onions
# Getting details for:  Carne Asada Recipe
# Getting details for:  BBQ Beef Short Ribs Recipe
# Getting details for:  Easy Meatball with Mixed Vegetables Recipe
# Getting details for:  Arroz a la Cubana Recipe
# Getting details for:  Easy Sweet and Sour Ikea Meatball Recipe
# Getting details for:  Corned Beef Guisado Recipe
# Getting details for:  Tasty Sliders Recipe
# Getting details for:  Beef Stir Fry with Chopped Broccoli Recipe
# Getting details for:  Beef with Broccoli Lo Mein Recipe
# Getting details for:  Beef Stew Recipe (How to Cook Beef Stew)
# Getting details for:  Beef Curry Recipe
# Getting details for:  Ground Beef Tostada
# Getting details for:  Shepherds Pie
# Getting details for:  New York Strip Steak with Sauteed Spinach Recipe
# Getting details for:  Pepper Crusted Filet Mignon Recipe
# Getting details for:  Round Steak in Criolla Sauce Recipe
# Getting details for:  Best Game Day Chili Recipe
# Getting details for:  Beef Stroganoff Recipe
# Getting details for:  How to Make Lengua a la Vinagreta
# Getting details for:  Adobo Steak Recipe
# Getting details for:  Beef in Oyster Sauce
# Getting details for:  Sizzling Bulalo Recipe
# Getting details for:  Braised Beef Recipe
# Getting details for:  Lengua in Mushroom Sauce
# Getting details for:  Soft Beef Tacos (Carne Asada)
# Getting details for:  Shared Recipe. Uncle Tom’s Crockpot Chili
# Getting details for:  Papaitan Recipe
# Getting details for:  Tortang Giniling Recipe
# Getting details for:  Callos Recipe
# Getting details for:  Shared Recipe: Tortang Talong with Giniling
# Getting details for:  Roast Beef
# Getting details for:  Meatloaf Recipe
# Getting details for:  Morcon Recipe
# Getting details for:  Beef Mami Recipe
# Getting details for:  Beef Mechado Recipe
# Getting details for:  Beef Nilaga Recipe
# Getting details for:  Homemade Beef Tapa
# Getting details for:  Beef Pochero Recipe
# Getting details for:  Bulalo Recipe
# Getting details for:  Lengua Estofada Recipe

# %%
df_dish = prepare_df(dish_dict)
df_dish
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Columns obtained for yeast: Index(['dry yeast'], dtype='object')
# Columns obtained for wrapper: Index(['lumpia wrapper', 'wonton wrapper'], dtype='object')
# Columns obtained for worcestershire_sauce: Index(['Worcestershire Sauce', 'Worcestershire sauce'], dtype='object')
# Columns obtained for winged_bean: Index(['winged bean'], dtype='object')
# Columns obtained for vinegar: Index(['Spiced Vinegar', 'coconut vinegar', 'red wine vinegar or cane vinegar',
#        'vinegar', 'white or apple cider vinegar', 'white or cane vinegar',
#        'white vinegar'],
#       dtype='object')
# Columns obtained for turmeric: Index([], dtype='object')
# Columns obtained for tomato: Index(['14.5 oz. can diced tomato', '6 oz can tomato paste',
#        '8 oz. can tomato sauce', '8oz. can tomato sauce',
#        'Filipino style tomato sauce', 'diced tomato', 'large plum tomato',
#        'medium plum tomato', 'medium ripe tomato', 'medium tomato',
#        'medium tomatoes', 'plum tomato', 'ripe tomato',
#        'small can tomato sauce', 'small tomato', 'tomato', 'tomato ketchup',
#        'tomato paste', 'tomato sauce', 'tomatoe ripe'],
#       dtype='object')
# Columns obtained for tofu: Index(['12 ounces extra firm tofu', 'deep fried extra firm tofu',
#        'deep fried tofu', 'extra firm tofu', 'tofu'],
#       dtype='object')
# Columns obtained for toasted_rice_powder: Index(['toasted rice powder'], dtype='object')
# Columns obtained for taro: Index(['taro'], dtype='object')
# Columns obtained for sweet_potato: Index(['sweet potato', 'sweet potato leaves'], dtype='object')
# Columns obtained for sugar: Index(['brown sugar', 'brown sugar or muscovado sugar', 'dark brown sugar',
#        'granulated white sugar', 'sugar', 'white sugar',
#        '• 1/2 teaspoon granulated white sugar'],
#       dtype='object')
# Columns obtained for star_anise: Index(['star anise'], dtype='object')
# Columns obtained for squash: Index(['340 g kalabasa (calabaza squash or butternut squash), cut into cubes',
#        'kalabasa (squash)', 'medium butternut squash or calabaza squash',
#        'small Butternut squash or kalabasa',
#        'small butternut squash or kalabasa', 'small opo squash'],
#       dtype='object')
# Columns obtained for soy_sauce: Index(['Soy sauce', 'dark soy sauce', 'light soy sauce', 'soy sauce',
#        '• 2 tablespoons soy sauce'],
#       dtype='object')
# Columns obtained for sinigang_mix: Index(['20 g pack Knorr Sinigang na Sampaloc Mix',
#        '20g pack Sinigang sa sampaloc mix',
#        '25g pack Knorr Sinigang na may Gabi Recipe Mix',
#        '40g pack Knorr Sinigang sa Sampaloc Mix Original',
#        '40g pack Knorr Sinigang sa Sampaloc mix', '40g pack sinigang mix',
#        'Knorr Sinigang sa Sampaloc', 'Knorr Sinigang sa Sampaloc Mix',
#        'Knorr Sinigang sa Sampaloc Mix Original',
#        'Knorr Sinigang sa Sampaloc Recipe Mix', 'Sinigang mix',
#        'sinigang mix'],
#       dtype='object')
# Columns obtained for shortening: Index(['shortening'], dtype='object')
# Columns obtained for sesame_oil: Index(['Sesame oil', 'sesame oil'], dtype='object')
# Columns obtained for scallion: Index([' scallions', 'bunch scallions', 'chopped scallion',
#        'chopped scallions', 'large bunch scallions', 'scallions',
#        'scallions minced'],
#       dtype='object')
# Columns obtained for sayote: Index(['sayote'], dtype='object')
# Columns obtained for salted_egg: Index(['salted eggs'], dtype='object')
# Columns obtained for safflower_oil: Index(['Safflower oil'], dtype='object')
# Columns obtained for raisins: Index(['raisins'], dtype='object')
# Columns obtained for radish: Index(['large daikon radish', 'medium Daikon radish', 'sliced daikon radish',
#        'small daikon radish'],
#       dtype='object')
# Columns obtained for potato: Index(['baking potato', 'large baking potato', 'large potato',
#        'medium baking potato', 'medium potato', 'medium sized potato',
#        'pc large potato', 'potato', 'potatoes', 'small baking potato',
#        'small potato'],
#       dtype='object')
# Columns obtained for pork_insides: Index(['Pig’s liver', 'beef small intestine', 'bung', 'cow’s small intestine',
#        'pig cheeks', 'pig heart', 'pig kidney', 'pig stomach', 'pig’s heart',
#        'pig’s liver', 'pig’s small intestine', 'pork ears', 'pork liver',
#        'small intestine'],
#       dtype='object')
# Columns obtained for pork_fat: Index(['pork fat or bacon grease'], dtype='object')
# Columns obtained for pork_stock: Index(['Knorr Pork Cube', 'Knorr Pork cube', 'Knorr pork cube',
#        'beef broth or pork broth', 'beef cube or pork cube', 'pork broth',
#        'pork cube', 'pork cubes', 'pork stock'],
#       dtype='object')
# Columns obtained for pork_blood: Index(['pork blood'], dtype='object')
# Columns obtained for pork_and_beans: Index(['pork and beans'], dtype='object')
# Columns obtained for pie_crust: Index(['chicken thighs cut into serving pieces',
#        'large banana pepper or 2 pieces siling pansigang',
#        'lemon or 2 pieces calamansi', 'lemon or 4 pieces calamansi',
#        'pie crust', 'pork belly. sliced into small pieces',
#        'small lemons or 6 to 7 pieces calamansi'],
#       dtype='object')
# Columns obtained for pickle: Index(['dill pickle cut into sticks', 'pickled dill or sweet pickled cucumber',
#        'sweet pickle relish', 'sweet relish'],
#       dtype='object')
# Columns obtained for pepper_leaf: Index(['Hot pepper leaves', 'fresh pepper leaves', 'hot pepper leaves'], dtype='object')
# Columns obtained for pechay: Index([' pechay', 'baby bok choy or pechay', 'pechay', 'pechay or bok choy',
#        'small bundle Pechay'],
#       dtype='object')
# Columns obtained for peanut: Index(['ground peanut', 'ground peanuts', 'ground roasted peanuts', 'peanut',
#        'peanut butter', 'peanuts', 'roasted peanuts'],
#       dtype='object')
# Columns obtained for patola: Index(['medium patola', 'small patola'], dtype='object')
# Columns obtained for parsley: Index(['chopped parsley', 'flat leaf parsley', 'parsley'], dtype='object')
# Columns obtained for paprika: Index(['paprika', 'smoked paprika'], dtype='object')
# Columns obtained for papaya: Index([' green papaya', 'pc small green papaya', 'small green papaya',
#        'small unripe papaya', 'unripe papaya'],
#       dtype='object')
# Columns obtained for oyster_sauce: Index(['oyster sauce'], dtype='object')
# Columns obtained for onion: Index([' red onion', ' white onion', 'Green onions', 'bunches of green onions',
#        'chopped green onions', 'chopped onion leeks', 'green chopped onions',
#        'green onion', 'green onions', 'large onion', 'large onions',
#        'large red onions', 'large yellow onion', 'medium onion',
#        'medium onions', 'medium red onion', 'medium sized onion',
#        'medium white onion', 'medium white or yellow onion',
#        'medium yellow onion', 'medium yellow onion sliced',
#        'medium yellow onions', 'medium yellow or white onion', 'onion',
#        'onion ', 'onion chopped', 'onion minced', 'onion powder', 'onions',
#        'red onion', 'small chopped onion', 'small onion', 'small red onion',
#        'small yellow onion', 'yellow onion'],
#       dtype='object')
# Columns obtained for olive_oil: Index(['extra virgin olive oil', 'olive oil'], dtype='object')
# Columns obtained for olive: Index(['Manzanilla olives', 'green olives'], dtype='object')
# Columns obtained for okra: Index(['okra'], dtype='object')
# Columns obtained for nutmeg: Index(['ground nutmeg'], dtype='object')
# Columns obtained for noodle: Index(['227 grams pancit canton (flour noodles)', 'Habhab noodles',
#        'Sotanghon', 'bihon noodles', 'egg noodles', 'fresh Miki noodles',
#        'fresh flat miki noodles', 'fresh miki noodles', 'fresh noodles',
#        'misua', 'miswa', 'round miki noodles', 'sotanghon',
#        'sotanghon noodles'],
#       dtype='object')
# Columns obtained for mushroom: Index(['10.5 oz. can condensed cream of mushroom', 'Shiitake mushroom',
#        'button mushroom', 'sliced button mushroom', 'sliced button mushrooms',
#        'white mushrooms'],
#       dtype='object')
# Columns obtained for munggo: Index(['mung beans'], dtype='object')
# Columns obtained for mirin: Index(['Mirin'], dtype='object')
# Columns obtained for mayonnaise: Index(['Lady's Choice Mayonnaise', 'Lady’s Choice Mayonnaise'], dtype='object')
# Columns obtained for malunggay: Index(['fresh malunggay leaves', 'malunggay', 'malunggay leaves'], dtype='object')
# Columns obtained for liver_spread: Index(['beef liver', 'chicken liver', 'liver spread', 'pig liver'], dtype='object')
# Columns obtained for lemongrass: Index([' lemongrass', 'bunch lemongrass', 'bunches lemongrass',
#        'large bunch lemongrass', 'lemongrass', 'stalk crushed lemongrass',
#        'stalk lemongrass', 'stalks lemongrass'],
#       dtype='object')
# Columns obtained for leeks: Index([], dtype='object')
# Columns obtained for lechon_sauce: Index(['Lechon Manok', 'Lechon manok sauce', 'Lechon sauce', 'lechon',
#        'lechon belly', 'lechon kawaii', 'lechon kawali', 'lechon sauce',
#        'leftover Lechon or Lechon kawali', 'pork lechon'],
#       dtype='object')
# Columns obtained for kasubha: Index(['kasubha'], dtype='object')
# Columns obtained for kangkong: Index(['baby spinach', 'bunch fresh spinach',
#        'bunch fresh spinach or kangkong', 'bunch kangkong',
#        'bunch of kangkong leaves with stalk', 'bunch spinach', 'kangkong',
#        'kangkong leaves', 'spinach'],
#       dtype='object')
# Columns obtained for jicama: Index(['jicama'], dtype='object')
# Columns obtained for jackfruit: Index(['sliced unripe jackfruit', 'unripe jackfruit'], dtype='object')
# Columns obtained for ice: Index(['Jasmine rice', 'Juice extracted from the shrimp head',
#        'Juice from 1 lemon', 'Pineapple juice', 'beef chuck sliced into cubes',
#        'carrot. sliced', 'cooked white rice', 'garlic fried rice',
#        'garlic fried rice.', 'glutinous rice', 'glutinous rice flour',
#        'glutinous rice flour diluted in 1/4 cup water',
#        'glutinous rice powder', 'ice cubes', 'jasmine rice',
#        'juice extracted from calamansi or lemon',
#        'juice from the canned tidbits', 'leftover rice', 'leftover white rice',
#        'lemon juice', 'pineapple juice', 'pineapple slices', 'rice',
#        'rice wash', 'rice washing', 'sliced banana blossoms', 'sliced hotdog',
#        'sliced turmeric', 'thumbs sliced ginger', 'white rice'],
#       dtype='object')
# Columns obtained for hotdog: Index(['beef franks or hotdog', 'hotdog', 'hotdogs', 'hotdogs or beef franks'], dtype='object')
# Columns obtained for hot_sauce: Index(['Frank's RedHot sauce', 'hot red chili pepper'], dtype='object')
# Columns obtained for honey: Index(['honey', 'honeycomb tripe'], dtype='object')
# Columns obtained for hoisin_sauce: Index(['hoisin sauce'], dtype='object')
# Columns obtained for green_pea: Index(['frozen green peas', 'green pea', 'green peas', 'pigeon pea'], dtype='object')
# Columns obtained for green_bean: Index(['bunch string beans', 'fresh long green beans', 'green beans',
#        'long green beans', 'sitaw', 'snake beans', 'snap peas', 'snow peas',
#        'string beans'],
#       dtype='object')
# Columns obtained for glutinous_rice: Index([], dtype='object')
# Columns obtained for ginger: Index([' ginger', 'ginger', 'ground ginger', 'minced ginger', 'thumb ginger',
#        'thumbs ginger', '⁄4 teaspoon ginger powder'],
#       dtype='object')
# Columns obtained for ginataang_gulay_mix: Index(['20g pack Knorr Ginataang Gulay mix',
#        '33 g packs Knorr Ginataang Gulay Mix',
#        '40g pack Knorr Ginataang Gulay Mix',
#        '45 g pack Knorr Ginataang Gulay Mix',
#        '45g pack Knorr Ginataang Gulay Recipe Mix',
#        'Knorr Ginataang Gulay mix', 'pack Knorr Ginataang Gulay Recipe Mix'],
#       dtype='object')
# Columns obtained for garlic: Index([' garlic', 'chili garlic oil', 'cloved crushed garlic', 'cloved garlic',
#        'crushed garlic', 'garlic', 'garlic ', 'garlic cloves',
#        'garlic crushed', 'garlic oil', 'garlic powder', 'head garlic',
#        'minced garlic', 'roasted garlic', 'thumb garlic', 'toasted garlic',
#        '⁄4 teaspoon garlic powder'],
#       dtype='object')
# Columns obtained for flour: Index(['all purpose flour', 'all-purpose flour', 'almond flour', 'cake flour',
#        'flour'],
#       dtype='object')
# Columns obtained for eggplant: Index(['Chinese eggplant', 'Chinese eggplants', 'eggplant', 'eggplant ',
#        'large Chinese eggplant', 'medium Chined eggplant',
#        'medium Chinese eggplant', 'medium eggplant', 'talong'],
#       dtype='object')
# Columns obtained for egg: Index(['Egg', 'boiled eggs', 'egg', 'egg yolk', 'eggs', 'fried eggs',
#        'hard boiled egg', 'hard boiled eggs', 'large eggs', 'quail eggs',
#        'raw egg', 'raw eggs'],
#       dtype='object')
# Columns obtained for curry_powder: Index(['curry powder'], dtype='object')
# Columns obtained for cucumber: Index([], dtype='object')
# Columns obtained for cream: Index(['all-purpose cream', 'coconut cream', 'table cream', 'whipping cream'], dtype='object')
# Columns obtained for cooking_wine: Index(['Shaoxing cooking wine', 'anisado wine', 'cooking wine'], dtype='object')
# Columns obtained for cooking_oil: Index(['cooking Oil', 'cooking oil', 'cooking oil plus 1 tablespoon extra',
#        'vegetable oil'],
#       dtype='object')
# Columns obtained for coconut_water: Index(['young coconut water'], dtype='object')
# Columns obtained for coconut_milk: Index(['coconut milk'], dtype='object')
# Columns obtained for coconut_meat: Index(['young coconut meat'], dtype='object')
# Columns obtained for clear_soda: Index(['7-Up', '7-up', 'Sprite'], dtype='object')
# Columns obtained for cinnamon: Index(['Cinnamon bark'], dtype='object')
# Columns obtained for sausage: Index(['Chorizo de Bilbao', 'chorizo de bilbao'], dtype='object')
# Columns obtained for chicken_stock: Index(['Knorr Chicken Cube', 'Knorr Chicken cube', 'Knorr chicken cube',
#        'chicken broth', 'chicken broth or stock'],
#       dtype='object')
# Columns obtained for chicharon: Index(['chicharon', 'crushed chicharon'], dtype='object')
# Columns obtained for cheese: Index(['cheddar cheese', 'shredded Cheddar cheese', 'shredded cheddar cheese',
#        'shredded sharp cheddar cheese', 'shredded/grated cheddar cheese'],
#       dtype='object')
# Columns obtained for celery: Index(['celery', 'celery ', 'chopped celery', 'stalks celery'], dtype='object')
# Columns obtained for carrot: Index(['carrot', 'carrots', 'carrots minced', 'chopped carrots',
#        'large carrot', 'large carrot minced', 'medium carrot',
#        'medium carrots', 'medium sized carrot', 'minced carrot',
#        'small carrot'],
#       dtype='object')
# Columns obtained for canned_meat: Index(['3 oz. can potted meat', 'luncheon meat'], dtype='object')
# Columns obtained for calamansi: Index(['Calamansi', 'calamansi', 'lemon', 'lemon lime soda',
#        'lemon or lime soda', 'lemon with rind', 'lime', 'lime or calamansi',
#        'small lemon'],
#       dtype='object')
# Columns obtained for cabbage: Index([' cabbage', 'Napa cabbage', 'bunch Napa cabbage', 'cabbage',
#        'chopped Napa cabbage', 'chopped cabbage', 'head medium cabbage',
#        'head small cabbage', 'medium cabbage', 'pc small cabbage',
#        'small cabbage'],
#       dtype='object')
# Columns obtained for butter: Index(['butter', 'margarine', 'margarine or butter', 'unsalted butter'], dtype='object')
# Columns obtained for broccoli: Index(['broccoli florets'], dtype='object')
# Columns obtained for bread: Index(['Panko bread crumbs', 'Panko breadcrumbs', 'bread crumbs',
#        'breadcrumbs', 'of loaf bread'],
#       dtype='object')
# Columns obtained for bok_choy: Index([' baby bok choy', ' bok choy', 'baby bok choy', 'bok choy',
#        'bunch baby bok choy', 'bunch bok choy', 'bunches baby bok choy',
#        'bunches baby bokchoy', 'bunches bok choy', 'bundles bok choy'],
#       dtype='object')
# Columns obtained for black_soda: Index(['Coke', 'cola drink'], dtype='object')
# Columns obtained for black_bean: Index(['Chinese black beans', 'salted black beans'], dtype='object')
# Columns obtained for beer: Index(['can root beer'], dtype='object')
# Columns obtained for beef_insides: Index(['beef bile to taste', 'beef heart', 'beef kidney', 'beef neck bone',
#        'beef neck bones', 'beef tripe', 'bile', 'blanket tripe', 'cow’s heart',
#        'lard', 'lengua', 'ox tongue', 'ox tripe'],
#       dtype='object')
# Columns obtained for beef_stock: Index(['Knorr Beef Cube', 'Knorr beef cube', 'beef bouillon',
#        'beef bouillon cube', 'beef broth', 'beef broth or sock',
#        'beef broth or water', 'beef cube',
#        'beef cubes dissolved in 3 cups boiling water', 'beef stock', 'bulalo',
#        'water or beef broth'],
#       dtype='object')
# Columns obtained for bay_leaf: Index(['bay leaves', 'did bay leaves', 'dried bay leaves'], dtype='object')
# Columns obtained for bamboo_shoots: Index([' Bamboo shoots'], dtype='object')
# Columns obtained for baking_powder: Index(['baking powder'], dtype='object')
# Columns obtained for annatto: Index(['Annatto powder', 'annatto oil', 'annatto paste', 'annatto powder',
#        'annatto powder or 1/2 cup annatto seeds soaked in 1/2 cup warm water',
#        'annatto seeds', 'annatto seeds diluted in water', 'annatto water'],
#       dtype='object')
# Columns obtained for ampalaya: Index(['ampalaya', 'ampalaya leaves'], dtype='object')
# Columns obtained for adobo_sauce: Index(['adobo sauce'], dtype='object')
# Columns obtained for achiote: Index(['achiote'], dtype='object')
# Columns obtained for tomato_liquid: Index(['Filipino Style Spaghetti Sauce', 'banana ketchup'], dtype='object')
# Columns obtained for banana_flower: Index(['banana blossom', 'banana blossoms', 'dried banana blossoms',
#        'small banana blossom', 'small fresh banana blossom'],
#       dtype='object')
# Columns obtained for pepper: Index(['Fish sauce and crushed peppercorn to taste',
#        'Fish sauce and ground black pepper to taste',
#        'Fish sauce and ground white pepper to taste', 'Ground black pepper',
#        'Ground black pepper and shrimp paste', 'Ground black pepper to taste',
#        'Patis and ground black pepper',
#        'Patis and ground black pepper to taste',
#        'Salt and ground black pepper to taste',
#        'Salt and ground white pepper to taste', 'crushed black pepper',
#        'crushed pepper', 'crushed peppercorn', 'crushed whole peppercorn',
#        'fish sauce and ground black pepper to taste', 'ground black pepper',
#        'ground black pepper to taste', 'ground white pepper',
#        'ground white pepper to taste', 'peppercorn', 'whole peppercorn',
#        '• A dash of ground black pepper'],
#       dtype='object')
# Columns obtained for chili: Index(['Jalapeno peppers', 'Serrano pepper', 'Serrano peppers', 'Thai chili',
#        'Thai chili or siling labuyo', 'Thai chili pepper',
#        'Thai chili pepper or siling labuyo', 'Thai chili peppers',
#        'Thai or birds eye chili', 'Thai or bird’s eye chili peppers',
#        'bird’s eye chili', 'chili', 'chili flakes', 'chili pepper',
#        'chili peppers', 'finger chilies', 'long green chili',
#        'long green chili pepper', 'long green chili peppers',
#        'long green pepper', 'medium Ghost Pepper', 'red pepper flakes',
#        'siling pansigang'],
#       dtype='object')
# Columns obtained for bell_pepper: Index([' green bell pepper', ' red bell pepper', 'bell pepper',
#        'green bell pepper', 'lareg red bell pepper', 'large red bell pepper',
#        'medium bell pepper', 'medium green bell pepper',
#        'medium red bell pepper', 'red bell pepper', 'small green bell pepper',
#        'small red bell pepper'],
#       dtype='object')
# Columns obtained for bagoong: Index(['alamang', 'bagoong alamang', 'balaw', 'sautéed shrimp paste',
#        'shrimp paste', 'spicy bagoong alamang'],
#       dtype='object')
# Columns obtained for liquid_seasoning: Index(['Knorr Liquid Seasoning', 'Knorr SavorRich Chicken Liquid Seasoning',
#        'Knorr SavorRich Chicken Liquid seasoning',
#        'Knorr SavorRich Liquid Seasoning', 'Knorr SavorRich Pork',
#        'Knorr SavorRich Pork Liquid Seasoning',
#        'Knorr SavorRich Pork Seasoning', 'Knorr liquid seasoning',
#        'Marinade ingredients:'],
#       dtype='object')
# Columns obtained for chickpea: Index(['15 oz. can chickpeas (garbanzos)', '16 oz. can chickpeas (garbanzos)',
#        'chick pea', 'chick peas', 'garbanzos'],
#       dtype='object')
# Columns obtained for chicken_insides: Index(['chicken gizzard', 'chicken heart'], dtype='object')
# Columns obtained for cornstarch: Index(['cornstarch', 'cornstarch diluted in 1/4 cup water',
#        'cornstarch diluted in 2 tablespoons water'],
#       dtype='object')
# Columns obtained for corned_beef: Index(['11.5 ounce can corned beef', '12 oz. can corned beef',
#        'canned corned beef', 'corned beef brisket'],
#       dtype='object')
# Columns obtained for fish_sauce: Index(['Fish sauce', 'Fish sauce to taste', 'fish sauce'], dtype='object')
# Columns obtained for pineapple_juice: Index([], dtype='object')
# Columns obtained for shrimp_cube: Index(['Knorr Shrimp cube', 'Knorr shrimp cube'], dtype='object')
# Columns obtained for watermelon: Index(['fresh watermelon'], dtype='object')
# Columns obtained for milk: Index(['evaporated milk', 'fresh milk', 'fresh milk or 1'], dtype='object')
# Columns obtained for pea: Index([], dtype='object')
# Columns obtained for pasta: Index(['Spaghetti', 'elbow macaroni', 'spaghetti',
#        'water for boiling chicken and macaroni'],
#       dtype='object')
# Columns obtained for shrimp: Index(['fresh shrimp', 'medium shrimp', 'shrimp'], dtype='object')
# Columns obtained for pineapple: Index(['Pineapple chunks', 'pineapple chunks', 'pineapple tidbits'], dtype='object')
# Columns obtained for water: Index(['Additional water for boiling', 'Water', 'Water ', 'Water for boiling',
#        'Water for steaming', 'cold water', 'water', 'water for boiling'],
#       dtype='object')
# Columns obtained for salt: Index(['Salt', 'Salt and pepper to taste', 'Salt to taste', 'coarse rock salt',
#        'coarse salt', 'coarse sea salt', 'salt', 'salt ',
#        'salt and pepper to taste', 'salt to taste'],
#       dtype='object')
# Columns obtained for rice: Index(['sinangag', 'sinangag na kanin'], dtype='object')
# Columns obtained for pork: Index(['4lb. Pig leg', 'Pork', 'Pork Hocks', 'Pork belly', 'Pork hock',
#        'Pork shoulder', 'grilled pork belly', 'ground pork', 'pig ears',
#        'pig face', 'pig tails', 'pork', 'pork belly', 'pork belly ',
#        'pork butt or loin', 'pork chop', 'pork chops', 'pork ham hock',
#        'pork hock', 'pork large intestine', 'pork leg', 'pork pata',
#        'pork ribs', 'pork shoulder', 'pork spare ribs', 'pork spareribs',
#        'pork tenderloin', 'pre-cleaned pork large intestines', 'whole pig leg',
#        'whole pork hock', 'whole slab boneless pork belly'],
#       dtype='object')
# Columns obtained for corn: Index(['Whole pepper corn', 'pcs Corn', 'sweet corn', 'whole pepper corn'], dtype='object')
# Columns obtained for chicken: Index(['2 to 3 lbs. whole chicken', 'Boneless chicken breasts', 'Chicken',
#        'Chicken breast', 'boneless chicken breast', 'chicken',
#        'chicken bouillon', 'chicken breast', 'chicken breasts',
#        'chicken drumstick', 'chicken drumsticks', 'chicken feet',
#        'chicken leg quarter', 'chicken leg quarters', 'chicken thigh',
#        'chicken thighs and drumstick', 'chicken wings', 'ground chicken',
#        'leftover chicken', 'skinless chicken breast', 'skinless chicken thigh',
#        'whole chicken'],
#       dtype='object')
# Columns obtained for beef: Index(['Beef chuck', 'Beef shank', 'Oxtail', 'beef', 'beef chuck',
#        'beef eye of round or flank steak', 'beef frank', 'beef franks',
#        'beef large intestine', 'beef ribs', 'beef shank', 'beef short rib',
#        'beef sirloin', 'beef tenderloin', 'beef tendon',
#        'eye of round or top sirloin steak', 'ground beef',
#        'leftover classic beef morcon', 'ox tail', 'recipe for beef pares',
#        'servings bistek tagalog', 'top sirloin'],
#       dtype='object')
# Columns obtained for banana: Index(['Saba banana', 'banana', 'large plaintain banana',
#        'medium ripe saba banana', 'plantain bananas', 'ripe plantain',
#        'ripe saba banana', 'ripe saba bananas', 'saba banana'],
#       dtype='object')
#                       dish_name  yeast  wrapper  worcestershire_sauce  \
# 0             Sinarsahang Manok    0.0      0.0                   0.0
# 1    Pinoy Chicken Curry Recipe    0.0      0.0                   0.0
# 2         Ketchup Fried Chicken    0.0      0.0                   0.0
# 3              Chicken Barbecue    0.0      0.0                   0.0
# 4         Chicken Paksiw Recipe    0.0      0.0                   0.0
# ..                          ...    ...      ...                   ...
# 277             Papaitan Recipe    0.0      0.0                   0.0
# 278               Morcon Recipe    0.0      0.0                   0.0
# 279         Beef Mechado Recipe    0.0      0.0                   0.0
# 280               Bulalo Recipe    0.0      0.0                   0.0
# 281      Lengua Estofada Recipe    0.0      0.0                   0.0
#
#      winged_bean  vinegar  turmeric  tomato  tofu  toasted_rice_powder  ...  \
# 0            0.0   0.0000       0.0     2.5   0.0                  0.0  ...
# 1            0.0   0.0000       0.0     0.0   0.0                  0.0  ...
# 2            0.0   0.3125       0.0     0.0   0.0                  0.0  ...
# 3            0.0   0.0000       0.0     0.0   0.0                  0.0  ...
# 4            0.0   0.5000       0.0     0.0   0.0                  0.0  ...
# ..           ...      ...       ...     ...   ...                  ...  ...
# 277          0.0   0.0000       0.0     0.0   0.0                  0.0  ...
# 278          0.0   0.0000       0.0     0.0   0.0                  0.0  ...
# 279          0.0   0.0000       0.0     1.0   0.0                  0.0  ...
# 280          0.0   0.0000       0.0     0.0   0.0                  0.0  ...
# 281          0.0   0.0000       0.0     1.0   0.0                  0.0  ...
#
#      shrimp  pineapple  water      salt  rice  pork   corn     chicken  \
# 0       0.0        0.0   1.50  0.000000   0.0   0.0  0.000  680.389364
# 1       0.0        0.0   1.00  0.000000   0.0   0.0  0.000  907.185819
# 2       0.0        0.0   0.00  0.000000   0.0   0.0  0.000    3.000000
# 3       0.0        0.0   0.00  2.000000   0.0   0.0  0.000    4.000000
# 4       0.0        0.0   1.00  1.000000   0.0   0.0  0.000  453.592909
# ..      ...        ...    ...       ...   ...   ...    ...         ...
# 277     0.0        0.0   8.00  0.156250   0.0   0.0  0.000    0.000000
# 278     0.0        0.0   0.00  0.005208   0.0   0.0  0.000    0.000000
# 279     0.0        0.0   1.00  1.000000   0.0   0.0  0.000    0.000000
# 280     0.0        0.0   4.25  0.000000   0.0   0.0  1.125    0.000000
# 281     0.0        0.0   3.00  0.000000   0.0   0.0  0.000    0.000000
#
#            beef  banana
# 0      0.000000     0.0
# 1      0.000000     0.0
# 2      0.000000     0.0
# 3      0.000000     0.0
# 4      0.000000     0.0
# ..          ...     ...
# 277  226.796455     0.0
# 278  907.185819     0.0
# 279  907.185819     0.0
# 280  907.185819     0.0
# 281    0.000000     0.0
#
# [282 rows x 137 columns]

# %%
export_sql(df_dish)
